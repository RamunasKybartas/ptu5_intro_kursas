# %% [markdown]
# # Pandas užduotys 2

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #  1 Sulipdykite iš 4 fragmentų vieną lentelę:
#
# fragmentus rasite [čia](https://github.com/robotautas/kursas/tree/master/Pandas/tops)
#
# * top_left = pd.read_csv('top1-25-1.csv')
# * top_right = pd.read_csv('top1-25-2.csv')
# * bottom_left = pd.read_csv('top26-50-1.csv')
# * bottom_right = pd.read_csv('top26-50-2.csv')
#
# pirmiausiai sujunkite apatinę dalį, tada viršutinę *(yra persidengiančių stulpelių!)*, galiausiai viršų su apačia. Naudokite **.concat()** ir **.merge()** metodus.

# %%
top_left = pd.read_csv('c:/codeacademy/ptu5_intro_kursas/pandas_lenteles/top25-1.csv')
top_right = pd.read_csv('c:/codeacademy/ptu5_intro_kursas/pandas_lenteles/top25-2.csv')
bottom_left = pd.read_csv('c:/codeacademy/ptu5_intro_kursas/pandas_lenteles/top50-1.csv')
bottom_right = pd.read_csv('c:/codeacademy/ptu5_intro_kursas/pandas_lenteles/top50-2.csv')

# %%
bottom = pd.concat([bottom_left, bottom_right], axis=1)

# %%
top = pd.merge(top_left, top_right, on=['Track.Name', 'Popularity'])

# %%
whole = pd.concat([top,bottom], sort=False)
whole.head()
# Out:
#                         Track.Name    Artist.Name           Genre  Popularity  \
# 0                         Senorita   Shawn Mendes    canadian pop        79.0
# 1                            China       Anuel AA  reggaeton flow        92.0
# 2    boyfriend (with Social House)  Ariana Grande       dance pop        85.0
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop         NaN
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap        94.0
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.
# 0      191               4             3
# 1      302               8             9
# 2      186              12            46
# 3      198              12            19
# 4      175              45             7

# %% [markdown]
# # 2 Sutvarkykite indeksą - padarykite, kad prasidėtų nuo 1.

# %%
whole['#'] = list(range(1, 51))
whole.set_index('#', inplace=True)
whole
# Out:
#          Artist.Name             Genre  Popularity  Beats.Per.Minute  Energy  \
# #
# 1       Shawn Mendes      canadian pop        79.0               117      55
# 2           Anuel AA    reggaeton flow        92.0               105      81
# 3      Ariana Grande         dance pop        85.0               190      80
# 4         Ed Sheeran               pop         NaN                93      65
# 5        Post Malone           dfw rap        94.0               150      65
# 6         Ed Sheeran               pop        84.0               102      68
# 7          Lil Tecca        trap music        92.0               180      64
# 8          Sam Smith               pop        90.0               111      68
# 9          Lil Nas X       country rap        87.0               136      62
# 10     Billie Eilish        electropop        95.0               135      43
# 11         Bad Bunny         reggaeton        93.0               176      62
# 12          DJ Snake         dance pop        86.0                96      71
# 13     Lewis Capaldi               pop        88.0               110      41
# 14              Sech    panamanian pop        87.0               176      79
# 15             Drake  canadian hip hop        92.0               101      50
# 16       Chris Brown         dance pop        82.0                93      45
# 17          J Balvin             latin        90.0               176      65
# 18       Post Malone           dfw rap        91.0                90      48
# 19               Y2K               NaN        88.0               130      39
# 20             Lizzo       escape room        91.0               158      62
# 21            MEDUZA         pop house        91.0               124      74
# 22         Lil Nas X       country rap        91.0               154      59
# 23       Jhay Cortez    reggaeton flow        83.0                92      79
# 24             Lunay             latin        91.0                92      78
# 25     Billie Eilish        electropop         NaN               135      45
# 26      Shawn Mendes      canadian pop        70.0               124      82
# 27       Tones and I    australian pop        83.0                98      59
# 28         Ali Gatie  canadian hip hop        89.0                96      46
# 29      Daddy Yankee             latin        91.0                94      86
# 30          J Balvin             latin        89.0                93      79
# 31  The Chainsmokers               edm        84.0                85      51
# 32     Ariana Grande         dance pop        89.0               140      32
# 33            Maluma         reggaeton        89.0                96      71
# 34        Young Thug       atl hip hop        89.0                98      59
# 35        Katy Perry         dance pop        89.0               100      88
# 36     Martin Garrix          big room        89.0               114      72
# 37              Sech    panamanian pop        91.0               176      70
# 38        Ed Sheeran               pop        87.0               152      82
# 39    Jonas Brothers          boy band        80.0               138      73
# 40              Lauv         dance pop        78.0                95      56
# 41              Kygo               edm        88.0               104      68
# 42      Taylor Swift         dance pop        90.0                85      68
# 43         Lady Gaga         dance pop        87.0                96      39
# 44            Khalid               pop        84.0               136      40
# 45           ROSALNA    r&b en espanol        88.0                98      69
# 46        Marshmello           brostep        88.0                88      62
# 47         Nicky Jam             latin        88.0               176      75
# 48        Marshmello           brostep         NaN               100      79
# 49  The Chainsmokers               edm        88.0               104      70
# 50        Ed Sheeran               NaN        82.0                95      79
#
#     Danceability  Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  \
# #
# 1             76              -6         8        75      191               4
# 2             79              -4         8        61      302               8
# 3             40              -4        16        70      186              12
# 4             64              -8         8        55      198              12
# 5             58              -4        11        18      175              45
# 6             80              -5         9        84      220               9
# 7             75              -6         7        23      131               2
# 8             48              -5         8        35      202              15
# 9             88              -6        11        64      157               5
# 10            70             -11        10        56      194              33
# 11            61              -5        24        24      251              60
# 12            82              -4        15        38      185              28
# 13            50              -6        11        45      182              75
# 14            73              -2         6        76      288               7
# 15            83              -4        12        10      205              10
# 16            70              -7        16        14      261              12
# 17            75              -6        11        43      243              15
# 18            76              -6         7        91      158              56
# 19            84              -8        14        50      161              18
# 20            72              -3        12        41      173              11
# 21            68              -7         7        63      153               4
# 22            70              -6        12        48      115              34
# 23            81              -4         9        58      309              14
# 24            80              -4        44        80      266              36
# 25            67             -11        12        68      195              25
# 26            69              -4        13        87      191              49
# 27            82              -6        18        54      210              69
# 28            73              -7        19        40      213              37
# 29            74              -3         6        66      193              11
# 30            64              -4        36        94      222               3
# 31            29              -8        10        36      210              12
# 32            78             -11         9        33      179              59
# 33            78              -5         9        68      176              22
# 34            80              -7        13        18      200               2
# 35            77              -5        32        39      224              19
# 36            66              -7        14        32      164              18
# 37            75              -5        11        62      226              14
# 38            72              -5        36        91      162              13
# 39            84              -5        11        95      181               4
# 40            81              -6         6        68      199              48
# 41            69              -7        10        40      228               2
# 42            77              -6         7        73      171               1
# 43            57              -6        23        32      216              37
# 44            90              -9         6        35      198               5
# 45            88              -4         5        75      162              39
# 46            66              -2        58        44      182               7
# 47            67              -4         8        80      202              24
# 48            69              -3        17        67      214              19
# 49            59              -6        41        50      218              23
# 50            75              -6         7        61      206              21
#
#     Speechiness.
# #
# 1              3
# 2              9
# 3             46
# 4             19
# 5              7
# 6              4
# 7             29
# 8              9
# 9             10
# 10            38
# 11            31
# 12             7
# 13             3
# 14            20
# 15             5
# 16            15
# 17            32
# 18             5
# 19             8
# 20            11
# 21             3
# 22             8
# 23             7
# 24             4
# 25            30
# 26             6
# 27            10
# 28             3
# 29             6
# 30            25
# 31             4
# 32            33
# 33            28
# 34            15
# 35             6
# 36             6
# 37            34
# 38             5
# 39             6
# 40             7
# 41             3
# 42             5
# 43             3
# 44            13
# 45            12
# 46             5
# 47             6
# 48             5
# 49             3
# 50            12

# %%
# Out:
#                         Track.Name    Artist.Name           Genre  Popularity  \
# #
# 1                         Senorita   Shawn Mendes    canadian pop        79.0
# 2                            China       Anuel AA  reggaeton flow        92.0
# 3    boyfriend (with Social House)  Ariana Grande       dance pop        85.0
# 4  Beautiful People (feat. Khalid)     Ed Sheeran             pop         NaN
# 5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap        94.0
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# #
# 1               117      55            76              -6         8        75
# 2               105      81            79              -4         8        61
# 3               190      80            40              -4        16        70
# 4                93      65            64              -8         8        55
# 5               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.
# #
# 1      191               4             3
# 2      302               8             9
# 3      186              12            46
# 4      198              12            19
# 5      175              45             7

# %% [markdown]
# # 3 Sukurkite grupavimo pagal žanrą objektą

# %% [markdown]
# # 4 kokie žanrai lentelėje pasitaiko daugiau negu 3 kartus?

# %%
# Out:
#                 Track.Name  Artist.Name  Popularity  Beats.Per.Minute  Energy  \
# Genre
# atl hip hop              1            1           1                 1       1
# australian pop           1            1           1                 1       1
# big room                 1            1           1                 1       1
# boy band                 1            1           1                 1       1
# brostep                  2            2           1                 2       2
#
#                 Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# Genre
# atl hip hop                1               1         1         1        1
# australian pop             1               1         1         1        1
# big room                   1               1         1         1        1
# boy band                   1               1         1         1        1
# brostep                    2               2         2         2        2
#
#                 Acousticness..  Speechiness.
# Genre
# atl hip hop                  1             1
# australian pop               1             1
# big room                     1             1
# boy band                     1             1
# brostep                      2             2

# %%
newdf[newdf['Energy']>3]['Energy']
# Out:
# Genre
# dance pop    8
# latin        5
# pop          6
# Name: Energy, dtype: int64

# %% [markdown]
# # 5 Koks žanras pats populiariausias? Koks mažiausiai populiarus?
# (pagal populiarumo vidurkį)

# %%
# Out:
# electropop 95.0
# canadian pop 74.5

# %% [markdown]
# # 6 Sukurkite lentelę, kurioje matytųsi, koks žanras turi aukščiausią vidurkį kiekviename indikatoriuje, bei pats vidurkis.
# kad nereikėtų daug vargti su stulpelių pavadinimais, galima juos ištraukti su **.columns.tolist()**

# %%
# Out:
#        Indikatorius          Žanras  Balai
# 0        Popularity      electropop     95
# 1  Beats.Per.Minute      trap music    180
# 2            Energy  reggaeton flow     80
# 3      Danceability  r&b en espanol     88
# 4    Loudness..dB..         brostep   -2.5
# 5          Liveness         brostep   37.5
# 6          Valence.        boy band     95
# 7           Length.  reggaeton flow  305.5
# 8    Acousticness..  australian pop     69
# 9      Speechiness.      electropop     34

# %% [markdown]
# # 7 Grįžkime prie sulipdytos lentelės. Ištraukite visas eilutes, kurios turi NaN reikšmių.
# *filtravimo sąlygose naudokite **.isnull()** funkciją.*

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 13 columns):
# Track.Name          50 non-null object
# Artist.Name         50 non-null object
# Genre               48 non-null object
# Popularity          47 non-null float64
# Beats.Per.Minute    50 non-null int64
# Energy              50 non-null int64
# Danceability        50 non-null int64
# Loudness..dB..      50 non-null int64
# Liveness            50 non-null int64
# Valence.            50 non-null int64
# Length.             50 non-null int64
# Acousticness..      50 non-null int64
# Speechiness.        50 non-null int64
# dtypes: float64(1), int64(9), object(3)
# memory usage: 5.5+ KB

# %%
# Out:
#                                        Track.Name    Artist.Name       Genre  \
# #
# 4                 Beautiful People (feat. Khalid)     Ed Sheeran         pop
# 19                                         Lalala            Y2K         NaN
# 25                   bad guy (with Justin Bieber)  Billie Eilish  electropop
# 48                                        Happier     Marshmello     brostep
# 50  Cross Me (feat. Chance the Rapper & PnB Rock)     Ed Sheeran         NaN
#
#     Popularity  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  \
# #
# 4          NaN                93      65            64              -8
# 19        88.0               130      39            84              -8
# 25         NaN               135      45            67             -11
# 48         NaN               100      79            69              -3
# 50        82.0                95      79            75              -6
#
#     Liveness  Valence.  Length.  Acousticness..  Speechiness.
# #
# 4          8        55      198              12            19
# 19        14        50      161              18             8
# 25        12        68      195              25            30
# 48        17        67      214              19             5
# 50         7        61      206              21            12

# %% [markdown]
# # 8 Stulpelyje 'Genre' NaN reikšmes pakeiskite į 'pop'

# %% [markdown]
# # 9 Stulpelyje 'Popularity' trūkstamas reikšmes pakeiskite į stulpelio vidurkį
